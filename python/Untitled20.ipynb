# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("info_sep1.csv")

# %%
s=pd.DataFrame(data.isnull().sum()!=10)
s
# Out:
#                         0
# Company              True
# Type                 True
# Traded as            True
# Industry             True
# Founded              True
# Headquarters         True
# Key people           True
# Products             True
# Revenue              True
# Operating income     True
# Net income           True
# Total assets         True
# Total equity         True
# Parent               True
# Website              True
# Number of employees  True
# ISIN                 True
# Founder              True
# Areas served         True
# Production output    True
# Number of locations  True
# Area served          True
# Services             True
# Subsidiaries         True
# Capital ratio        True
# Owner                True
# Divisions            True
# Formerly             True
# AUM                  True

# %%
df=data[data.isnull().sum()!=10]
# Out:
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_2316\2182631683.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df=data[data.isnull().sum()!=10]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df=data[data.isnull().sum()!=10]
#
# File d:\indic\lib\site-packages\pandas\core\frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#    3500 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File d:\indic\lib\site-packages\pandas\core\frame.py:3549, in DataFrame._getitem_bool_array(self, key)
# ...

# %%
df=data[(data['Company']=='Adani Power Ltd.') | (data['Company']=='Britannia Industries Ltd.') | (data['Company']=='Hindustan Aeronautics Ltd.') | (data['Company']=='Tata Motors Ltd.') | (data['Company']=='Tech Mahindra Ltd.') | (data['Company']=='Unichem Laboratories Ltd.') | (data['Company']=='Reliance Industrial Infrastructure Ltd.') | (data['Company']=='Ircon International Ltd.') | (data['Company']=='Union Bank Of India') | (data['Company']=='Bharat Dynamics Ltd.')] 
# dt=data[data['Company']=='Britannia Industries Ltd.'] 
# d0=data[data['Company']=='Hindustan Aeronautics Ltd.'] 
# d1=data[data['Company']=='Tata Motors Ltd.']
# d2=data[data['Company']=='Zomato Ltd.']
# d3=data[data['Company']=='Unichem Laboratories Ltd.']
# d4=data[data['Company']=='Reliance Industrial Infrastructure Ltd.']
# d5=data[data['Company']=='Ircon International Ltd.']
# d6=data[data['Company']=='Union Bank Of India']
# d7=data[data['Company']=='Bharat Dynamics Ltd.']

# %%
df
# Out:
#                                      Company  \
# 0                           Adani Power Ltd.
# 7                  Britannia Industries Ltd.
# 17                Hindustan Aeronautics Ltd.
# 41                          Tata Motors Ltd.
# 42                        Tech Mahindra Ltd.
# 65                      Bharat Dynamics Ltd.
# 154                      Union Bank Of India
# 232                 Ircon International Ltd.
# 289  Reliance Industrial Infrastructure Ltd.
# 323                Unichem Laboratories Ltd.
#
#                                  Type  \
# 0                              Public
# 7                              Public
# 17          Public Sector Undertaking
# 41                             Public
# 42                             Public
# 65          Public Sector Undertaking
# 154                            Public
# 232     Subsidiary of Indian Railways
# 289  Public (BSE: 523445) (NSE: RIIL)
# 323                            Public
#
# ...

# %%
df.to_csv("info_sep1.csv",index=False)

# %%
df
# Out:
#             Company    Type                     Traded as Industry  \
# 0  Adani Power Ltd.  Public  BSE: 533096, NSE: ADANIPOWER   Energy
#
#           Founded                                     Headquarters  \
# 0  22 August 1996  Shantigram, Khodiyar, Ahmedabad, Gujarat, India
#
#                                           Key people  \
# 0  Gautam Adani\n(Chairman)\nAnil Sardana\n(MD an...
#
#                                             Products  \
# 0  Sale and distribution, electricity generation ...
#
#                                        Revenue  \
# 0  ₹28,149.68 crore (US$3.7 billion) (2021)[1]
#
#                           Operating income  ... Region Director  \
# 0  ₹7,395.07 crore (US$970 million) (2021)  ...    NaN      NaN
#
#   Romanized name Successor Author Publisher Publication date Text  \
# 0            NaN       NaN    NaN       NaN              NaN  NaN
#
#   Picture format Sister channels
# 0            NaN             NaN
#
# [1 rows x 118 columns]

# %%
df.append(dt)
df.append(d0)
df.append(d1)
df.append(d2)
df.append(d3)
df.append(d4)
df.append(d5)
df.append(d6)
df.append(d6)
df.append(d7)
# Out:
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_2316\487061893.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(dt)
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_2316\487061893.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(d0)
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_2316\487061893.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(d1)
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_2316\487061893.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(d2)
# ...

# %%
df
# Out:
#             Company    Type                     Traded as Industry  \
# 0  Adani Power Ltd.  Public  BSE: 533096, NSE: ADANIPOWER   Energy
#
#           Founded                                     Headquarters  \
# 0  22 August 1996  Shantigram, Khodiyar, Ahmedabad, Gujarat, India
#
#                                           Key people  \
# 0  Gautam Adani\n(Chairman)\nAnil Sardana\n(MD an...
#
#                                             Products  \
# 0  Sale and distribution, electricity generation ...
#
#                                        Revenue  \
# 0  ₹28,149.68 crore (US$3.7 billion) (2021)[1]
#
#                           Operating income  ... Region Director  \
# 0  ₹7,395.07 crore (US$970 million) (2021)  ...    NaN      NaN
#
#   Romanized name Successor Author Publisher Publication date Text  \
# 0            NaN       NaN    NaN       NaN              NaN  NaN
#
#   Picture format Sister channels
# 0            NaN             NaN
#
# [1 rows x 118 columns]
