# %%
import pandas as pd
import openpyxl

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\indic\scripts\python.exe -m pip install --upgrade pip' command.
#   Using cached openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
data = pd.read_excel('master_dataset_companies.xlsx')

# %%
data
# Out:
#                                        name             domain  year founded  \
# 0                                     tekla          tekla.com        1966.0
# 1     american national standards institute           ansi.org           NaN
# 2                 construction data company        cdcnews.com        1975.0
# 3                        promise technology        promise.com        1988.0
# 4                                 collabnet         collab.net        1999.0
# ...                                     ...                ...           ...
# 5482                  robins air force base                NaN           NaN
# 5483                                momenta  momentaglobal.com        2000.0
# 5484                electronic data systems            eds.com        1962.0
# 5485                       fujitsu services                NaN           NaN
# 5486                       fujitsu services                NaN           NaN
#
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# name
# domain
# year founded
# industry
# size range
# locality
# country
# linkedin url
# current employee estimate
# total employee estimate
# index_name
# name_wiki
# Website
# Founded
# Headquarters
# Type
# logo_1
# Industry
# Number of employees
# Key people
# Founder
# Products
# Revenue
# Area served
# Parent
# Net income
# Location
# Owner
# Operating income
# Total assets
# Defunct
# Fate
# Total equity
# Coordinates
# Established
# logo_2
# logo_caption_2
# Subsidiaries
# Services
# Traded as
# Number of locations
# Formerly
# Founders
# URL
# Motto
# Launched
# Successor
# Predecessor
# Campus
# logo_caption_1
# Type of site
# President
# Divisions
# Country
# Current status
# Native name
# Genre
# Formation
# Available in
# Principal
# Students
# Born
# Registration
# Language
# Affiliations
# Trade name
# Commercial
# Former names
# Academic staff
# Mascot
# Colors
# Type of business
# Grades
# Nickname
# Key people
# Publisher
# Area served
# Died
# Purpose
# ...

# %%
data.describe()
# Out:
#        year founded  current employee estimate  total employee estimate  \
# count   3106.000000                5487.000000              5487.000000
# mean    1998.684482                 555.834153              1366.524877
# std       18.904155                6717.709254             16225.415722
# min     1814.000000                   0.000000                 1.000000
# 25%     1994.000000                   1.000000                 4.000000
# 50%     2002.000000                   8.000000                28.000000
# 75%     2010.000000                  59.000000               180.500000
# max     2018.000000              274047.000000            716906.000000
#
#          index_name
# count  5.487000e+03
# mean   1.984616e+06
# std    2.228138e+06
# min    0.000000e+00
# 25%    1.789840e+05
# 50%    9.685050e+05
# 75%    3.350658e+06
# max    7.152769e+06

# %%
x=pd.DataFrame(data.isnull().sum())

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
#       1 for i in x:
# ----> 2     print(i[1])
#
# TypeError: 'int' object is not subscriptable

# %%
df=data[data['country']=='india']
df
# Out:
#                           name                    domain  year founded  \
# 37       technopark trivandrum            technopark.org        1990.0
# 239   amity university gurgaon                       NaN           NaN
# 317                  pine labs              pinelabs.com        1998.0
# 354                        sap                       NaN        2017.0
# 389            infosys limited                       NaN        1981.0
# ...                        ...                       ...           ...
# 4630    bharti infotel limited                       NaN           NaN
# 5155     manpower professional                 pmc.co.in           NaN
# 5270               sumit kumar  texaskidneyinstitute.com           NaN
# 5360              lenovo india                       NaN        2005.0
# 5424             digital india       digitalindia.gov.in        2014.0
#
#                                  industry   size range  \
# 37    information technology and services    201 - 500
# ...

# %%
df.describe(include=['category'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 df.describe(include=['category'])
#
# File d:\indic\lib\site-packages\pandas\core\generic.py:10235, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9986 @final
#    9987 def describe(
#    9988     self: NDFrameT,
#    (...)
#    9992     datetime_is_numeric=False,
#    9993 ) -> NDFrameT:
#    9994     """
#    9995     Generate descriptive statistics.
#    9996
#    (...)
#   10233     max            NaN      3.0
#   10234     """
# > 10235     return describe_ndframe(
#   10236         obj=self,
#   10237         include=include,
#   10238         exclude=exclude,
#   10239         datetime_is_numeric=datetime_is_numeric,
#   10240         percentiles=percentiles,
#   10241     )
#
# ...

# %%
df.drop('Enrollment',axis=1)
# Out:
#                           name                    domain  year founded  \
# 37       technopark trivandrum            technopark.org        1990.0
# 239   amity university gurgaon                       NaN           NaN
# 317                  pine labs              pinelabs.com        1998.0
# 354                        sap                       NaN        2017.0
# 389            infosys limited                       NaN        1981.0
# ...                        ...                       ...           ...
# 4630    bharti infotel limited                       NaN           NaN
# 5155     manpower professional                 pmc.co.in           NaN
# 5270               sumit kumar  texaskidneyinstitute.com           NaN
# 5360              lenovo india                       NaN        2005.0
# 5424             digital india       digitalindia.gov.in        2014.0
#
#                                  industry   size range  \
# 37    information technology and services    201 - 500
# ...

# %%
df[df['Rating']>3.5]
# Out:
#                              Name  Rating Reviews Company_type  \
# 0                             TCS     3.9   16.1k       Public
# 1                       Accenture     4.0   14.1k      Private
# 2                      ICICI Bank     4.1   12.7k       Public
# 3                       Cognizant     3.9   12.1k      Private
# 4                       HDFC Bank     4.0   10.9k       Public
# ...                           ...     ...     ...          ...
# 9885  Sgt Medical College Hosp...     3.6      27      Private
# 9897             Simeio Solutions     4.0      27      Private
# 9904        Orange Retail Finance     3.8      27      Private
# 9968  Al Arrab Contracting Com...     4.1      27      Private
# 9977                  Internshala     4.5      27      Private
#
#              Headquater Years old   Employees
# 0     Mumbai + 156 more        52      10000+
# 1      Dublin + 87 more        31      10000+
# 2     Mumbai + 723 more        26      10000+
# ...
