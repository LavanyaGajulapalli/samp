# %%
import pandas as pd

# %%
data1=pd.read_csv("tr_bse_nse_company_to_isin")

# %%
data1.columns
# Out:
# Index(['Company_name', 'Company_name_tr', 'BSE code', 'BSE code Tel',
#        'NSE code', 'NSE code Tel', 'ISIN'],
#       dtype='object')

# %%
data1
# Out:
#                                     Company_name  \
# 0                         Adani Enterprises Ltd.
# 1                        Adani Green Energy Ltd.
# 2     Adani Ports and Special Economic Zone Ltd.
# 3                           Adani Total Gas Ltd.
# 4                        Adani Transmission Ltd.
# ...                                          ...
# 4105                          Zodiac Energy Ltd.
# 4106                         Zodiac-JRD-MKJ Ltd.
# 4107                        Zodiac Ventures Ltd.
# 4108                   Zuari Agro Chemicals Ltd.
# 4109                           Zuari Global Ltd.
#
#                                         Company_name_tr  BSE code  \
# 0                         అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్    512599
# 1                          అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్    541450
# 2     అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...    532921
# 3                           అదానీ టోటల్ గ్యాస్ లిమిటెడ్    542066
# ...

# %%
data2=pd.read_csv("tr_nse_bse_description1 to regstate.csv")

# %%
data2.columns
# Out:
# Index(['Description', 'Description Tel', 'REGISTRAR_OF_COMPANIES',
#        'REGISTRAR_OF_COMPANIES Tel', 'REGISTERED_OFFICE_ADDRESS',
#        'REGISTERED_OFFICE_ADDRESS Tel',
#        'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN',
#        'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN Tel', 'REGISTERED_STATE',
#        'REGISTERED_STATE Tel'],
#       dtype='object')

# %%
data3=pd.read_csv("tr_nse_bse_cpclass_to_regidate.csv")

# %%
data3.columns
# Out:
# Index(['COMPANY_STATUS', 'COMPANY_STATUS_Tel', 'COMPANY_CLASS',
#        'COMPANY_CLASS Tel', 'COMPANY_CATEGORY', 'COMPANY_CATEGORY Tel',
#        'COMPANY_SUB_CATEGORY', 'COMPANY_SUB_CATEGORY Tel',
#        'DATE_OF_REGISTRATION', 'DATE_OF_REGISTRATION Tel'],
#       dtype='object')

# %%
data4=pd.read_csv("tr_nse_bse_sec to serstby.csv")

# %%
data4.columns
# Out:
# Index(['Security Type Description', 'Security Type Description Tel',
#        'ISIN Status', 'ISIN Status Tel', 'Address Of Issuer',
#        'Address Of Issuer Tel', 'Contact Person Details',
#        'Contact Person Details Tel',
#        'Name of Registrar & Transfer Agent (RTA)',
#        'Name of Registrar & Transfer Agent (RTA) Tel',
#        'RTA Business Partner (BP) ID', 'RTA Business Partner (BP) ID Tel',
#        'Address for Physical Certificate',
#        'Address for Physical Certificate ID Tel', 'Services stopped by RTA',
#        'Services stopped by RTA Tel', 'Sector', 'Sector Tel', 'Industry',
#        'Industry Tel'],
#       dtype='object')

# %%
data5=pd.read_csv("tr_nse_bse_isindes to formerif.csv")

# %%
data5.columns
# Out:
# Index(['Former Name(if any)', 'Former Name(if any) Tel', 'ISIN Description',
#        'ISIN Description Tel', 'Name Of Issuer', 'Name Of Issuer Tel'],
#       dtype='object')

# %%
data=pd.read_csv("final_nse_bse.csv")

# %%
data.columns
# Out:
# Index(['Company', 'BSE code', 'NSE code', 'ISIN', 'Sector', 'Industry', 'Date',
#        'Price', '1 day change(%)', '52 Week Low', '52 Week High',
#        'Market Cap(Cr)', 'Enterprise Value(Cr)', 'ISIN Description',
#        'Name Of Issuer', 'Former Name(if any)', 'Security Type Description',
#        'ISIN Status', 'Face Value (INR)', 'Address Of Issuer',
#        'Contact Person Details', 'Name of Registrar & Transfer Agent (RTA)',
#        'RTA Business Partner (BP) ID', 'Address for Physical Certificate',
#        'Tel. No.', 'Fax No.', 'Email ID(s)',
#        'No. of demat requests pending for >21 days', 'Services stopped by RTA',
#        'url', 'company size', 'pincode', 'CIN', 'COMPANY_STATUS',
#        'COMPANY_CLASS', 'COMPANY_CATEGORY', 'COMPANY_SUB_CATEGORY',
#        'DATE_OF_REGISTRATION', 'REGISTERED_STATE', 'AUTHORIZED_CAP',
#        'PAIDUP_CAPITAL', 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN',
# ...

# %%
d={'Company':data['Company']}

# %%
s=pd.DataFrame(d)

# %%
s['Description Tel']=data['Description']

# %%
s
# Out:
#                                          Company  \
# 0                         Adani Enterprises Ltd.
# 1                        Adani Green Energy Ltd.
# 2     Adani Ports and Special Economic Zone Ltd.
# 3                           Adani Total Gas Ltd.
# 4                        Adani Transmission Ltd.
# ...                                          ...
# 4105                          Zodiac Energy Ltd.
# 4106                         Zodiac-JRD-MKJ Ltd.
# 4107                        Zodiac Ventures Ltd.
# 4108                   Zuari Agro Chemicals Ltd.
# 4109                           Zuari Global Ltd.
#
#                                             Company Tel  BSE code  \
# 0                         అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్    512599
# 1                          అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్    541450
# 2     అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...    532921
# 3                           అదానీ టోటల్ గ్యాస్ లిమిటెడ్    542066
# ...

# %%
s.to_csv("tr_bse_nse_te.csv",index=False)

# %%
s['52 Week High Tel']=data['52 Week High']

# %%
s['Market Cap(Cr)']=data['Market Cap(Cr)']

# %%
data['No. of demat requests pending for >21 days'].unique()
# Out:
# array(['NOT APPLICABLE', nan], dtype=object)

# %%
a={'Company':data1['Company_name_tr']}

# %%
x=pd.DataFrame(a)

# %%
x['Description']=data['Description Tel']

# %%
x
# Out:
#                                                 Company  BSE code  \
# 0                         అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్    512599
# 1                          అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్    541450
# 2     అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...    532921
# 3                           అదానీ టోటల్ గ్యాస్ లిమిటెడ్    542066
# 4                         అదానీ ట్రాన్స్‌మిషన్ లిమిటెడ్    539254
# ...                                                 ...       ...
# 4105                          జోడియాక్ ఎనర్జీ లిమిటెడ్.    543416
# 4106                        రాశిచక్రం-JRD-MKJ లిమిటెడ్.    512587
# 4107                        జోడియాక్ వెంచర్స్ లిమిటెడ్.    503641
# 4108                    జువారీ ఆగ్రో కెమికల్స్ లిమిటెడ్    534742
# 4109                            జువారీ గ్లోబల్ లిమిటెడ్    500780
#
#            NSE code          ISIN                 Sector  \
# 0         అడానియంట్  INE423A01024                  సేవలు
# ...

# %%
x.to_csv("translated_bse_nse.csv",index=False)

# %%
import pandas as pd

# %%
d=pd.read_csv("translated_bse_nse.csv")

# %%
d['company size'].unique()
# Out:
# array(['Giant', 'Large', 'Medium', 'Small', 'Tiny'], dtype=object)

# %%
d['company size'].replace(['Giant', 'Large', 'Medium', 'Small', 'Tiny'],['దిగ్గజం','పెద్ద','మధ్యస్థ','చిన్నది','చిన్న'],inplace=True )

# %%
# Out:
# array(['దిగ్గజం', 'పెద్ద', 'మధ్యస్థ', 'చిన్నది', 'చిన్న'], dtype=object)

# %%
d.columns
# Out:
# Index(['Company', 'BSE code', 'NSE code', 'ISIN', 'Sector', 'Industry', 'Date',
#        'Price', '1 day change(%)', '52 Week Low', '52 Week High',
#        'Market Cap(Cr)', 'Enterprise Value(Cr)', 'ISIN Description',
#        'Name Of Issuer', 'Former Name(if any)', 'Security Type Description',
#        'ISIN Status', 'Face Value (INR)', 'Address Of Issuer',
#        'Contact Person Details', 'Name of Registrar & Transfer Agent (RTA)',
#        'RTA Business Partner (BP) ID', 'Address for Physical Certificate ID',
#        'Tel. No.', 'Fax No.', 'Email ID(s)',
#        'No. of demat requests pending for >21 days', 'Services stopped by RTA',
#        'url', 'company size', 'pincode', 'CIN', 'COMPANY_STATUS',
#        'COMPANY_CLASS', 'COMPANY_CATEGORY', 'COMPANY_SUB_CATEGORY',
#        'DATE_OF_REGISTRATION', 'REGISTERED_STATE', 'AUTHORIZED_CAP',
#        'PAIDUP_CAPITAL', 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN',
# ...

# %%
d['No. of demat requests pending for >21 days'].unique()
# Out:
# array(['NOT APPLICABLE', nan], dtype=object)

# %%
d['No. of demat requests pending for >21 days'].replace(['NOT APPLICABLE'],['వర్తించదు'],inplace=True )

# %%
d['COMPANY_STATUS'].unique()
# Out:
# array(['ACTV', nan, 'క్రియాశీల సంస్థ', 'ఈఫైలింగ్ కోసం అందుబాటులో లేదు',
#        'చురుకుగా', 'సమ్మేళనం', 'అమల్', 'కొట్టివేయు', 'ULQD', 'దుమ్ము',
#        'NAEF'], dtype=object)

# %%
d['COMPANY_STATUS'].replace(['ACTV'],['చురుకుగా'],inplace=True )

# %%
d
# Out:
#                                                 Company  BSE code  \
# 0                         అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్    512599
# 1                          అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్    541450
# 2     అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...    532921
# 3                           అదానీ టోటల్ గ్యాస్ లిమిటెడ్    542066
# 4                         అదానీ ట్రాన్స్‌మిషన్ లిమిటెడ్    539254
# ...                                                 ...       ...
# 4105                          జోడియాక్ ఎనర్జీ లిమిటెడ్.    543416
# 4106                        రాశిచక్రం-JRD-MKJ లిమిటెడ్.    512587
# 4107                        జోడియాక్ వెంచర్స్ లిమిటెడ్.    503641
# 4108                    జువారీ ఆగ్రో కెమికల్స్ లిమిటెడ్    534742
# 4109                            జువారీ గ్లోబల్ లిమిటెడ్    500780
#
#            NSE code          ISIN                 Sector  \
# 0         అడానియంట్  INE423A01024                  సేవలు
# ...

# %%
d.to_csv("new_translated.csv")
