# %%
#!/usr/bin/env python

from jinja2 import Environment, FileSystemLoader


file_loader = FileSystemLoader('templates')
env = Environment(loader=file_loader)

template = env.get_template('b.txt')

output = template.render(companies=data[0:2])
print(output)
# Out:
# అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్ 02 మార్చి 1993న స్థాపించబడిన పబ్లిక్. ఇది ప్రభుత్వేతర కంపెనీగా వర్గీకరించబడింది మరియు రిజిస్ట్రార్ ఆఫ్ కంపెనీస్, అహ్మదాబాద్‌లో నమోదు చేయబడింది. దీని అధీకృత వాటా మూలధనం రూ. 4,904,200,200 మరియు దాని చెల్లించిన మూలధనం రూ. 1,099,800,060. ఇది రుసుము లేదా కాంట్రాక్ట్ ప్రాతిపదికన హోల్‌సేల్‌లో చేర్చబడుతుంది. [కమీషన్ ఏజెంట్లు, కమోడిటీ బ్రోకర్లు మరియు వేలం నిర్వాహకులు మరియు ఇతరుల తరపున మరియు వారి ఖాతాలో వ్యాపారం చేసే ఇతర టోకు వ్యాపారులందరినీ కలిగి ఉంటుంది. స్వయం ఉపాధి వేలం పాటదారుల కార్యకలాపాలు 74991లో చేర్చబడ్డాయి.]
#
# అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్ యొక్క వార్షిక సాధారణ సమావేశం (AGM) చివరిగా 12 జూలై 2021న జరిగింది మరియు కార్పొరేట్ వ్యవహారాల మంత్రిత్వ శాఖ (MCA) రికార్డుల ప్రకారం, దాని బ్యాలెన్స్ షీట్ చివరిగా 31 మార్చి 2021న దాఖలు చేయబడింది.
#
# అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్ డైరెక్టర్‌లు వినయ్ ప్రకాష్, హేమంత్ నెరుర్కర్ మధుసూదన్, నరేంద్ర మైర్‌పాడి, వెంకటరామన్ సుబ్రమణియన్, గౌతమ్ శాంతిలాల్ అదానీ, రాజేష్ శాంతిలాల్ అదానీ, ప్రణవ్ వినోద్ అదానీ, విజయ్ లక్ష్మీ జోషి, .
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('tr_nse_bse_description1 to regstate.csv')

# %%
data=df

# %%
import csv

# %%
input_file = csv.DictReader(open("tr_nse_bse_description1 to regstate.csv"))

# %%
import pandas as pd

dict = {row[0] : row[1] for _, row in pd.read_csv("tr_nse_bse_description1 to regstate.csv").iterrows()}

# %%
import pandas as pd

dict_from_csv = pd.read_csv('tr_nse_bse_description1 to regstate.csv', header=None, index_col=0, squeeze=True).to_dict()
print(dict_from_csv)
# Out:
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_7072\3101053834.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   dict_from_csv = pd.read_csv('tr_nse_bse_description1 to regstate.csv', header=None, index_col=0, squeeze=True).to_dict()
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import csv
reader = csv.reader(open('tr_nse_bse_description1 to regstate.csv', 'r'))
d = {}
for row in reader:
   k, v = row
   d[k] = v
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [45], in <cell line: 4>()
#       2 reader = csv.reader(open('tr_nse_bse_description1 to regstate.csv', 'r'))
#       3 d = {}
# ----> 4 for row in reader:
#       5    k, v = row
#       6    d[k] = v
#
# File D:\\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 1615: character maps to <undefined>

# %%
import csv
import json

# %%
f = open('csvjson (1).json',encoding="utf8")

# %%
data = json.load(f)

# %%
for i in data:
    print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %%
data[0:5]
# Out:
# [{'Description': "Adani Enterprises Limited is a Public incorporated on 02 March 1993. It is classified as Non-govt company and is registered at Registrar of Companies, Ahmedabad. Its authorized share capital is Rs. 4,904,200,200 and its paid up capital is Rs. 1,099,800,060. It is inolved in Wholesale on a fee or contract basis. [Includes commission agents, commodity brokers and auctioneers and all other wholesalers who trade on behalf and on the account of others. Activities of self employed auctioneers are included in 74991.]\n\nAdani Enterprises Limited's Annual General Meeting (AGM) was last held on 12 July 2021 and as per records from Ministry of Corporate Affairs (MCA), its balance sheet was last filed on 31 March 2021.\n\nDirectors of Adani Enterprises Limited are Vinay Prakash, Hemant Nerurkar Madhusudan, Narendra Mairpady, Venkataraman Subramanian, Gautam Shantilal Adani, Rajesh Shantilal Adani, Pranav Vinod Adani, Vijay Laxmi Joshi, .\n\nAdani Enterprises Limited's Corporat
# ...

# %%
for i in data:
    print(i['COMPANY_STATUS'])
# Out:
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
#
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
#
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active company
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Not available for efiling
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active company
# ACTV
# ACTV
# ACTV
# Active
# Active
# Active company
#
# Active
# Active company
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active company
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active
# Active
# Active company
# Active
# ACTV
# Active company
# ACTV
# Active
# Active
# ACTV
# ACTV
# Active
# Active
# ACTV
# ACTV
# Active company
# Active
# Active company
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active
# Active company
#
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active
# Active
# Active
#
# Active
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# ACTV
# Active
# ACTV
# ACTV
# ACTV
# Active company
# ...
